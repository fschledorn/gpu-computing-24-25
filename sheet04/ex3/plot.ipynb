# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt("ex01.csv", delimiter=",")

print(data)

for i in range(6):
    plt.plot(data[i::6,0], data[i::6, 2], "o-", label=f"{data[i::6,1][0]}")
    #plt.xscale("log")
    # plt.yscale("log")
plt.legend()
# Out:
# [[1.02400000e+03 3.20000000e+01 3.75939876e-01]
#  [1.02400000e+03 6.40000000e+01 5.87048292e-01]
#  [1.02400000e+03 1.28000000e+02 7.03915536e-01]
#  [1.02400000e+03 2.56000000e+02 7.82396138e-01]
#  [1.02400000e+03 5.12000000e+02 7.81250000e-01]
#  [1.02400000e+03 1.02400000e+03 7.85468876e-01]
#  [2.04800000e+03 3.20000000e+01 5.80025375e-01]
#  [2.04800000e+03 6.40000000e+01 8.85445476e-01]
#  [2.04800000e+03 1.28000000e+02 1.16788328e+00]
#  [2.04800000e+03 2.56000000e+02 1.40443277e+00]
#  [2.04800000e+03 5.12000000e+02 1.55038774e+00]
#  [2.04800000e+03 1.02400000e+03 1.56250000e+00]
#  [3.07200000e+03 3.20000000e+01 6.47467434e-01]
#  [3.07200000e+03 6.40000000e+01 1.04166663e+00]
#  [3.07200000e+03 1.28000000e+02 1.47058821e+00]
#  [3.07200000e+03 2.56000000e+02 1.88679242e+00]
#  [3.07200000e+03 5.12000000e+02 2.05215907e+00]
#  [3.07200000e+03 1.02400000e+03 2.32558155e+00]
#  [4.09600000e+03 3.20000000e+01 6.91704929e-01]
#  [4.09600000e+03 6.40000000e+01 1.16374218e+00]
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt("ex03.csv", delimiter=",")

plt.plot(data[:,0], data[:, 1]/1e6, "o-")
plt.xlabel("Stride")
plt.ylabel("Clock Cycles / $10^6$")
# Out:
# Text(0, 0.5, 'Clock Cycles / $10^6$')
